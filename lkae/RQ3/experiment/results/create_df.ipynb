# %%
# then for every variation of the dataset in ds, run the experiment with each retriever and save the results
import pickle as pkl
import pandas as pd
import json, os, jsonlines

from lkae.utils.data_loading import root_dir
from lkae.utils.scoring import eval_run_custom_nofile

out_dir = './'
data = []

split = 'train_dev_combined'
dataset_split = f'English_{split}'


# ground truth RQ3
gold_file = os.path.join(root_dir, 'data', f'{dataset_split}.jsonl')
gold_list = [line for line in jsonlines.open(gold_file)]


selected_variations = ["nopre-nam-bio", "nopre-nonam-nobio", "pre-nam-bio", "pre-nonam-nobio"]

# load each config and construct its retriever
setups = {}

with open('../config.json', 'r') as file:
    configs = json.load(file)

    for config in configs['configs']:
        exp_fingerprint = f'{config["retriever_method"]}__{config["verifier_method"]}'
        
        
        setups[exp_fingerprint] = {}
        setups[exp_fingerprint]['retriever'] = config["retriever_method"]
        setups[exp_fingerprint]['verifier'] = config["verifier_method"]


for dataset_variation in selected_variations:
    for exp_fingerprint in setups:

        run_filename = f'{out_dir}/{dataset_variation}_{exp_fingerprint}.pkl'

        # check if the file already exists from a previous run
        if os.path.exists(run_filename):
            # print(f'found {run_filename}, loading from file')
            verification_results = pkl.load(open(run_filename, 'rb'))
        else:
            print(f'file {run_filename} not found, skipping')

        macro_f1, strict_macro_f1 = eval_run_custom_nofile(verification_results, gold_list)

        retriever_label, verifier_label = exp_fingerprint.split('__')

        # print(
        #     f"result for verification run - Macro-F1: {macro_f1:.4f} Strict-Macro-F1: {strict_macro_f1:.4f} with retriever: {retriever_label} and retriever: {verifier_label}"
        # )

        data.append({
            'Macro-F1': macro_f1,
            'Strict-Macro-F1': strict_macro_f1,
            'Retrieval_Method': retriever_label, 
            'Verifier_Method': verifier_label, 
            'DS_Settings': dataset_variation,
        })

# Convert the list of dictionaries to a DataFrame
df_verification = pd.DataFrame(data)

# Display the DataFrame
df_sorted = df_verification.sort_values(by='Macro-F1', ascending=False)

# add an overall rank column based on the Macro-F1 score
# it displays the index in the dataframe for each row
ranks = []
rank = 0
last_score = 1.0
for idx,row in df_sorted.iterrows():
    if row['Macro-F1'] < last_score:
        rank += 1
        last_score = row['Macro-F1']
    ranks.append(rank)

df_sorted['Rank'] = ranks

# move rank column to the front
df_sorted = df_sorted[['Rank', 'Macro-F1', 'Strict-Macro-F1', 'Retrieval_Method', 'Verifier_Method', 'DS_Settings']]

display(df_sorted)
# len(df_sorted)
# Out:
#     Rank  Macro-F1  Strict-Macro-F1    Retrieval_Method       Verifier_Method  \
# 17     1  0.858523         0.850470  rerank-nv-embed-v1             openai-4o
# 24     2  0.854713         0.846412  rerank-nv-embed-v1             openai-4o
# 10     3  0.850244         0.842376  rerank-nv-embed-v1             openai-4o
# 3      4  0.844351         0.840080  rerank-nv-embed-v1             openai-4o
# 2      5  0.810380         0.797802  rerank-nv-embed-v1        openai-4o-mini
# 9      6  0.803897         0.795360  rerank-nv-embed-v1        openai-4o-mini
# 23     7  0.793172         0.784668  rerank-nv-embed-v1        openai-4o-mini
# 16     8  0.781789         0.768742  rerank-nv-embed-v1        openai-4o-mini
# 12     9  0.776465         0.768775  rerank-nv-embed-v1          llama3-1-70b
# 27    10  0.773538         0.754840  rerank-nv-embed-v1         llama3-1-405b
# 13    11  0.740946         0.730040  rerank-nv-embed-v1         llama3-1-405b
# 26    12  0.731470         0.715628  rerank-nv-embed-v1          llama3-1-70b
# 5     13  0.721766         0.709036  rerank-nv-embed-v1          llama3-1-70b
# 19    14  0.705238         0.692306  rerank-nv-embed-v1          llama3-1-70b
# 20    15  0.704749         0.689438  rerank-nv-embed-v1         llama3-1-405b
# 6     16  0.704116         0.688744  rerank-nv-embed-v1         llama3-1-405b
# 25    17  0.652548         0.641708  rerank-nv-embed-v1           llama3-1-8b
# 18    18  0.615837         0.605200  rerank-nv-embed-v1           llama3-1-8b
# 11    19  0.588212         0.576674  rerank-nv-embed-v1           llama3-1-8b
# 4     20  0.517222         0.510842  rerank-nv-embed-v1           llama3-1-8b
# 7     21  0.322321         0.322321  rerank-nv-embed-v1  transformers-roberta
# 21    22  0.312231         0.303788  rerank-nv-embed-v1  transformers-roberta
# 1     23  0.298747         0.280012  rerank-nv-embed-v1     transformers-bart
# 8     24  0.283468         0.275085  rerank-nv-embed-v1     transformers-bart
# 15    25  0.270719         0.270719  rerank-nv-embed-v1     transformers-bart
# 14    26  0.264516         0.264516  rerank-nv-embed-v1  transformers-roberta
# 0     27  0.225579         0.216021  rerank-nv-embed-v1  transformers-roberta
# 22    28  0.219048         0.210490  rerank-nv-embed-v1     transformers-bart
#
#           DS_Settings
# 17        pre-nam-bio
# 24    pre-nonam-nobio
# 10  nopre-nonam-nobio
# 3       nopre-nam-bio
# 2       nopre-nam-bio
# 9   nopre-nonam-nobio
# 23    pre-nonam-nobio
# 16        pre-nam-bio
# 12  nopre-nonam-nobio
# 27    pre-nonam-nobio
# 13  nopre-nonam-nobio
# 26    pre-nonam-nobio
# 5       nopre-nam-bio
# 19        pre-nam-bio
# 20        pre-nam-bio
# 6       nopre-nam-bio
# 25    pre-nonam-nobio
# 18        pre-nam-bio
# 11  nopre-nonam-nobio
# 4       nopre-nam-bio
# 7   nopre-nonam-nobio
# 21    pre-nonam-nobio
# 1       nopre-nam-bio
# 8   nopre-nonam-nobio
# 15        pre-nam-bio
# 14        pre-nam-bio
# 0       nopre-nam-bio
# 22    pre-nonam-nobio

# %%
# filter df_sorted for only the best result for each verifier_method
df_best = df_sorted.groupby('Verifier_Method').head(1)

df_best
# Out:
#     Rank  Macro-F1  Strict-Macro-F1    Retrieval_Method       Verifier_Method  \
# 17     1  0.858523         0.850470  rerank-nv-embed-v1             openai-4o
# 2      5  0.810380         0.797802  rerank-nv-embed-v1        openai-4o-mini
# 12     9  0.776465         0.768775  rerank-nv-embed-v1          llama3-1-70b
# 27    10  0.773538         0.754840  rerank-nv-embed-v1         llama3-1-405b
# 25    17  0.652548         0.641708  rerank-nv-embed-v1           llama3-1-8b
# 7     21  0.322321         0.322321  rerank-nv-embed-v1  transformers-roberta
# 1     23  0.298747         0.280012  rerank-nv-embed-v1     transformers-bart
#
#           DS_Settings
# 17        pre-nam-bio
# 2       nopre-nam-bio
# 12  nopre-nonam-nobio
# 27    pre-nonam-nobio
# 25    pre-nonam-nobio
# 7   nopre-nonam-nobio
# 1       nopre-nam-bio
