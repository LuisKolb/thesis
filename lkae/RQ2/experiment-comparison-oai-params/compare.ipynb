# %%
import os
import json
import jsonlines
import time
import pandas as pd
from IPython.display import display

from lkae.utils.data_loading import pkl_dir, load_pkl, load_pkls, root_dir, AuredDataset
from lkae.verification.verify import get_verifier
from lkae.utils.scoring import eval_run_custom_nofile
from lkae.verification.verify import Judge, run_verifier_on_dataset
from lkae.utils.data_loading import AuthorityPost

datasets = load_pkls(pkl_dir)

# possilbe splits: train, dev, train_dev_combined
# (test, all_combined don't have "labels")
split = 'train_dev_combined'

dataset_split = f'English_{split}'
qrel_filename = f'{dataset_split}_qrels.txt'

dataset_variations_dict = datasets[dataset_split]
print(dataset_variations_dict.keys())
# Out:
# PyTerrier 0.10.1 has loaded Terrier 5.10 (built by craigm on 2024-08-22 17:33) and terrier-helper 0.0.8
# dict_keys(['nopre-nam-bio', 'nopre-nam-nobio', 'nopre-nonam-bio', 'nopre-nonam-nobio', 'pre-nam-bio', 'pre-nam-nobio', 'pre-nonam-bio', 'pre-nonam-nobio'])

# %%
# ground truth RQ2
gold_file = os.path.join(root_dir, 'data', f'{dataset_split}.jsonl')
gold_list = [line for line in jsonlines.open(gold_file)]

# select a set of variations of the dataset
selected_variations = ["nopre-nonam-nobio"] # openai should handle raw data fine, no need to preprocess

# %%
# load each config and construct its verifier

verifiers = {}

with open('config-compare.json', 'r') as file:
    configs = json.load(file)

    for config in configs['configs']:
        verifier_label = get_verifier(**config)
        verifiers[config['verifier_method']] = verifier_label

verifiers
# Out:
# {'openai-4o-mini-run1': <lkae.verification.models.openai_verifier.OpenaiVerifier at 0x140bf6118d0>,
#  'openai-4o-mini-run2': <lkae.verification.models.openai_verifier.OpenaiVerifier at 0x140bf610430>,
#  'openai-4o-mini-run3': <lkae.verification.models.openai_verifier.OpenaiVerifier at 0x140b95facb0>,
#  'openai-4o-mini-run4': <lkae.verification.models.openai_verifier.OpenaiVerifier at 0x140b9618af0>}

# %%
# compare outputs for different verifiers on one dataset
# first get judgements for all verifiers

# get the dataset
selected_variation = selected_variations[0]
dataset: AuredDataset = dataset_variations_dict[selected_variation]
dataset = dataset[:]
for i, item in enumerate(dataset):
    retrieved_ev = []
    evidences = item["evidence"]
    if evidences is None:
        print(f"skipped {i} because no evidence")
        continue
    for ev in evidences:
        retrieved_ev.append(AuthorityPost(ev.url, ev.post_id, ev.text, 1, 1))
    dataset[i]["retrieved_evidence"] = retrieved_ev

solomon = Judge(
    scale=False,  # ignore scaling, weigh each evidence evenly, except for confidence score given by verifier
    ignore_nei=True,  # ignore NEI predictions
)

results = {}
for verifier_label in verifiers:
    start = time.time()

    verification_results = run_verifier_on_dataset(
        dataset=dataset,
        verifier=verifiers[verifier_label],
        judge=solomon,
        blind=False,
    )

    macro_f1, strict_macro_f1 = eval_run_custom_nofile(verification_results, gold_list)

    results[verifier_label] = {
        "res_dict": verification_results,
        "time": time.time() - start,
        "macro_f1": macro_f1,
        "strict_f1": strict_macro_f1,
        "settings": {"verifier": verifier_label, "dataset": selected_variation},
    }
# Out:
# -----total token usage for verification-----
# total tokens:	105717
# prompt tokens:	101030
# completion tokens:	4687
# price estimate:	$1.15091
# run failed with status: failed, returning NOT ENOUGH INFO answer
# could not json-parse response from openai model: {"decision": "NOT ENOUGH INFO", confidence": 1.0}
# -----total token usage for verification-----
# total tokens:	105362
# prompt tokens:	100715
# completion tokens:	4647
# price estimate:	$1.14656
# -----total token usage for verification-----
# total tokens:	105692
# prompt tokens:	101030
# completion tokens:	4662
# price estimate:	$1.15016
# -----total token usage for verification-----
# total tokens:	105692
# prompt tokens:	101030
# completion tokens:	4662
# price estimate:	$1.15016

# %%
print(json.dumps(results, indent=2))
# Out:
# {
#   "openai-4o-mini-run1": {
#     "res_dict": [
#       {
#         "id": "AuRED_014",
#         "label": "REFUTES",
#         "claim": "\u201c#Urgent / Ramallah Ministry of Health spokesman Kamal Al-Shakhra: We received 2,000 doses of the American \u201cModerna\u201d #Corona vaccine, and this batch will be designated for President Abbas, the Fatah Central Committee, and VIPs.\u201d",
#         "predicted_label": "REFUTES",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/palestine_moh",
#             "1357211717479116800",
#             "Statement from Authority Account \"palestine_moh\": \"Pictures from the launch of the vaccination campaign against the #Coronavirus, starting with the medical and health teams in #Bethlehem. #vaccine #Palestine #COVID19 https://t.co/vnhGmoZtgC\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/palestine_moh",
#             "1356683687870488576",
#             "Statement from Authority Account \"palestine_moh\": \"The Ministry added that the second group that will receive the vaccine is the elderly over the age of 60 and those with chronic diseases, because if they are infected with the virus, they will be more susceptible to serious symptoms. #vaccine #modernavaccine #palestine #COVID19\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/palestine_moh",
#             "1356683511047028748",
#             "Statement from Authority Account \"palestine_moh\": \"Yesterday, the Ministry of Health announced that it had received 2,000 doses of Moderna vaccine, stressing that the priority in receiving anti-Coronavirus vaccinations is for personnel working in the health sector, as they are the group who have the most contact with patients and are most at risk of infection with the Corona virus. #modernavaccine #palestine #COVID19\"",
#             0.85
#           ],
#           [
#             "https://twitter.com/palestine_moh",
#             "1356683390733471746",
#             "Statement from Authority Account \"palestine_moh\": \"The Minister of Health, Dr. #May_Alkaila, today, Tuesday, the campaign, where she received the #vaccine at Hogochaffer Hospital in Turmus Aya, while the medical staff working in the intensive care rooms there were vaccinated with the #Moderna vaccine. #modernavaccine #palestine #COVID19\"",
#             0.0
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_037",
#         "label": "REFUTES",
#         "claim": "Macron to Sky News: After my visit to Mrs. Fairouz last night and the visit to the Jaj Cedar Reserve, I realized the love of a large section of the Lebanese people for their President of the Republic. Fairouz also told me about her appreciation and love for the President and the reform project that the President of the Republic wants to implement. I also salute the President of the Republic and his efforts and patience. https://t.co/7pMab8yWCD",
#         "predicted_label": "REFUTES",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/salmanonline",
#             "1301079467889131522",
#             "Statement from Authority Account \"salmanonline\": \"RT @HalaHomsi: Macron and Mrs. Fairouz: This news was not published by \u201cSky News\u201d FactCheck https://tinyurl.com/u67kpve3 via @Annahar #FactCheck @salmanonline\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/salmanonline",
#             "1301067546200858626",
#             "Statement from Authority Account \"salmanonline\": \"Good morning, Beirut.. But this is fabricated news, and supporters of the Free Patriotic Movement are not convinced that Macron did not tell Sky News at all. He did not make any statement, neither he nor Fayrouz, such words. Good morning, Beirut #fake_news https://t.co/7KVkbCAI42\"",
#             0.9
#           ],
#           [
#             "https://twitter.com/salmanonline",
#             "1300798719751794688",
#             "Statement from Authority Account \"salmanonline\": \"This news attributed to Sky News Arabia is false https://t.co/Mlf8QKDr7W\"",
#             0.0
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_085",
#         "label": "REFUTES",
#         "claim": "Saudi Arabia evacuated 10 students from China in a plane that could accommodate 500 passengers, and did not evacuate 170 Yemeni students with it, while participating with 100 warplanes to bomb Yemen. May God protect the Sultanate of Oman for sending a private plane to the Yemeni students stranded in China. And what a good neighbor, Oman \u2764\ufe0f https://t. co/OfDSIoD5ry",
#         "predicted_label": "NOT ENOUGH INFO",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/YSUCORG",
#             "1226482043007066113",
#             "Statement from Authority Account \"YSUCORG\": \"RT @Yemen_PM: The Yemeni Embassy in #China announces the start of disbursing financial aid to all Yemeni students and their families residing in the Chinese city of #Wuhan, which is witnessing the spread of the Corona virus, in the coming days.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/YSUCORG",
#             "1225345358961762304",
#             "Statement from Authority Account \"YSUCORG\": \"Statement by the administrative body of the Yemeni Students Union in China regarding the conditions of students in Wuhan https://t.co/5xAH0YORF8\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/Yemen_PM",
#             "1226202744475865089",
#             "Statement from Authority Account \"Yemen_PM\": \"The Yemeni Embassy in #China announces the start of disbursing financial aid to all Yemeni students and their families residing in the Chinese city of #Wuhan, which is witnessing the spread of the Corona virus, in the coming days.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/Yemen_PM",
#             "1224702545127407617",
#             "Statement from Authority Account \"Yemen_PM\": \"Deputy Prime Minister Dr. Salem Al-Khanbashi chairs an expanded meeting to study precautionary arrangements to prevent the spread of the #Coronavirus to #Yemen... noting the directives of Prime Minister Dr. Maeen Abdulmalik to form an emergency committee and take all measures to protect students and the Yemeni community in China. https://t.co/WEKYfJcpaQ\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/Yemen_PM",
#             "1224372681870651392",
#             "Statement from Authority Account \"Yemen_PM\": \"Prime Minister Dr. Maeen Abdulmalik makes a phone call with the Charg\u00e9 d'Affaires of the Yemeni Embassy in China, Ahmed Jaber, to check on the conditions of the students and the Yemeni community... stressing that the government, under the directives of the President of the Republic, will provide, in coordination with the Chinese authorities, all support to maintain their safety as a result of the outbreak of the Corona virus https:// t.co/UK2xfjBMYk\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/Yemen_PM",
#             "1224361944959922178",
#             "Statement from Authority Account \"Yemen_PM\": \"The Prime Minister\u2019s directives included speeding up the disbursement of additional financial aid to Yemeni students in the Chinese city of Wuhan, which was directed after the spread of the Corona virus, as well as completing the transfer of third-quarter dues to students on scholarship in China and disbursing their dues for the fourth quarter in an exceptional and urgent manner.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/Yemen_PM",
#             "1224361941986050049",
#             "Statement from Authority Account \"Yemen_PM\": \"Prime Minister Dr. Maeen Abdulmalik chairs an emergency meeting on the Corona virus and the necessary measures to protect students and the Yemeni community in #China and directs the formation of an emergency committee headed by Deputy Prime Minister Salem Al-Khanbashi to follow up on students and members of the community stranded in the city of Wuhan, and ways to evacuate them and give them full health care https:// t.co/0SWSLUSq3M\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/yemen_mofa",
#             "1225075510461583362",
#             "Statement from Authority Account \"yemen_mofa\": \"The Minister of Foreign Affairs discussed with the Ambassador of the People's Republic of China to our country the conditions of Yemeni nationals in China, especially students and residents of the city of Wuhan, and the necessary arrangements to provide them with the necessary needs and the possibility of their evacuation, stressing the sending of additional financial aid to our children in the city of Wuhan. https://t.co/bRGSMzTLfZ\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/alimohsnalahmar",
#             "1224728227136131073",
#             "Statement from Authority Account \"alimohsnalahmar\": \"The Vice President of the Republic expresses his wishes to the Yemeni students, the Yemeni community, and friends in China for safety due to the spread of the virus and for this crisis to end with the least losses.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/alimohsnalahmar",
#             "1224727797043814400",
#             "Statement from Authority Account \"alimohsnalahmar\": \"The Vice President stresses the importance of making maximum efforts to protect students and the Yemeni community there and intensifying communication with the Chinese side, supporting parties, brothers and friends in a way that will prevent them from being infected with the virus and prevent the epidemic from reaching our country.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/alimohsnalahmar",
#             "1224725042845704193",
#             "Statement from Authority Account \"alimohsnalahmar\": \"The Vice President of the Republic, in his meeting with the Minister of Public Health and Population, follows up on the efforts made to protect Yemeni students in China from infection with the Corona virus and preventive measures in this aspect, in implementation of the directives of His Excellency Abd Rabbuh Mansour Hadi, President of the Republic https://t.co/CNbBGtrQfk\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/yemenembassymu1",
#             "1225286729332150273",
#             "Statement from Authority Account \"yemenembassymu1\": \"RT @yemen_mofa: The Minister of Foreign Affairs discussed with the Ambassador of the People\u2019s Republic of China to our country the conditions of Yemeni nationals in China, especially students and residents of the city of Wuhan, and the necessary arrangements to provide them with the necessary needs and the possibility of their evacuation, stressing the sending of additional financial aid to our children in the city of Wuhan.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/yemenembassymu1",
#             "1224919667661295618",
#             "Statement from Authority Account \"yemenembassymu1\": \"RT @Yemen_PM: Prime Minister Dr. Maeen Abdulmalik chairs an emergency meeting on the Corona virus and the necessary measures to protect students and the Yemeni community in #China and directs the formation of an emergency committee headed by Deputy Prime Minister Salem Al-Khanbashi to follow up on students and members of the community stranded in the city of Wuhan, and ways to evacuate them and give them full health care.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/yemenembassymu1",
#             "1224919598698565633",
#             "Statement from Authority Account \"yemenembassymu1\": \"RT @alimohsnalahmar: The Vice President of the Republic, in his meeting with the Minister of Public Health and Population, is following up on the efforts made to protect Yemeni students in China from being infected with the Corona virus and the preventive measures in this aspect, in implementation of the directives of His Excellency President Abd Rabbuh Mansour Hadi, President of the Republic.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/yemenembassymu1",
#             "1224919545057619968",
#             "Statement from Authority Account \"yemenembassymu1\": \"RT @alimohsnalahmar: The Vice President stresses the importance of exerting maximum efforts to protect students and the Yemeni community there and intensifying communication with the Chinese side, supporting bodies, brothers and friends in a way that will prevent them from being infected with the virus and prevent the epidemic from reaching our country.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/yemenembassymu1",
#             "1224919523691827202",
#             "Statement from Authority Account \"yemenembassymu1\": \"RT @alimohsnalahmar: The Vice President of the Republic expresses his wishes to the Yemeni students, the Yemeni community, and friends in China for safety due to the spread of the virus and for this crisis to end with the least losses.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/yemenembassymu1",
#             "1224208762606686209",
#             "Statement from Authority Account \"yemenembassymu1\": \"RT @yemen_mofa: We are in direct contact with our students in the city of Wuhan, where the Corona virus has spread, and under the guidance of the country\u2019s leadership, we are coordinating with the Chinese authorities and our embassy in China and arranging the necessary procedures to provide what they need and discussing the possibility of evacuating them with the relevant authorities.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/ye_embassy_cn",
#             "1226177350376685569",
#             "Statement from Authority Account \"ye_embassy_cn\": \"We are pleased to announce that financial aid will be disbursed to all Yemeni citizens residing in the city of Wuhan during the next week, immediately after coordination with the Foreign Affairs Office in the city of Wuhan is completed. We highly value the commitment of our dear citizens to the instructions of the Chinese government to ensure their safety. May you always be well.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/ye_embassy_cn",
#             "1226116927015141376",
#             "Statement from Authority Account \"ye_embassy_cn\": \"RT @ChineseEmbtoYEM: Let's listen to the words from the Yemeni student in Wuhan, China. https://t.co/qiGLv6DY57\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/ye_embassy_cn",
#             "1225068691332550662",
#             "Statement from Authority Account \"ye_embassy_cn\": \"Al-Hadrami discusses with the Chinese ambassador the conditions of Yemenis residing in Wuhan - Saba Net :: Saba Net https://t.co/8hpZljVTrR\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/ye_embassy_cn",
#             "1224546827657048064",
#             "Statement from Authority Account \"ye_embassy_cn\": \"The Prime Minister reassures students and the Yemeni community in China - Saba Net :: Saba Net https://t.co/7dVfiC61Pr\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/ye_embassy_cn",
#             "1224347860436582400",
#             "Statement from Authority Account \"ye_embassy_cn\": \"The Prime Minister directs to take all necessary measures to protect students and the Yemeni community in China from Corona - Saba Net :: Saba Net https://t.co/YlFLvDuowW\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/ye_embassy_cn",
#             "1224339041534898179",
#             "Statement from Authority Account \"ye_embassy_cn\": \"We are in constant contact with the students in Wuhan, and a working group has been established that has completed the necessary proposals and statements and submitted them to decision makers. We hope everyone will be patient, and we highly appreciate the Chinese government\u2019s care, attention, and provision of the needs of everyone in their homes.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/ye_embassy_cn",
#             "1224153761511198720",
#             "Statement from Authority Account \"ye_embassy_cn\": \"RT @yemen_mofa: We are in direct contact with our students in the city of Wuhan, where the Corona virus has spread, and under the guidance of the country\u2019s leadership, we are coordinating with the Chinese authorities and our embassy in China and arranging the necessary procedures to provide what they need and discussing the possibility of evacuating them with the relevant authorities.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/AlbarkaniS",
#             "1224264648142151680",
#             "Statement from Authority Account \"AlbarkaniS\": \"Our hearts are with you and our prayers are with you. We ask God to protect you and our Chinese friends from the evil and danger of this virus.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/AlbarkaniS",
#             "1224264646913187842",
#             "Statement from Authority Account \"AlbarkaniS\": \"Our brothers and sons who are in the friendly Republic of China, we pray for safety for you and for your Chinese friends, and Allah willing, the disaster will be overcome. The leadership is following what is happening, and your appeals, especially those in Wuhan, are of concern, and Allah willing, the issue will be addressed urgently.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/ChineseEmbtoYEM",
#             "1226159605815947264",
#             "Statement from Authority Account \"ChineseEmbtoYEM\": \"Universities and the Chinese government provide food to Yemeni students in Wuhan. Here is the process of distributing food to Yemeni students. We are with you, let us make joint efforts to overcome this difficult period! \ud83c\udde8\ud83c\uddf3\u2764\ufe0f\ud83c\uddfe\ud83c\uddea https://t.co/X780HRFaZv\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/ChineseEmbtoYEM",
#             "1226159298398556160",
#             "Statement from Authority Account \"ChineseEmbtoYEM\": \"Universities and the Chinese government provide food to Yemeni students in Wuhan. Let us make joint efforts to overcome this difficult period!\ud83c\udde8\ud83c\uddf3\u2764\ufe0f\ud83c\uddfe\ud83c\uddea https://t.co/wgVtrBxR9X\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/ChineseEmbtoYEM",
#             "1226093838357405696",
#             "Statement from Authority Account \"ChineseEmbtoYEM\": \"Let's listen to the words of the Yemeni student in Wuhan, China. https://t.co/qiGLv6DY57\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/ChineseEmbtoYEM",
#             "1225418369857413120",
#             "Statement from Authority Account \"ChineseEmbtoYEM\": \"The ambassador met with Sheikh Abdul Salam Al-Khudairi today, Undersecretary of the Ministry of Endowments and Guidance. The two sides discussed the Corona virus in China and the situation of Yemeni expatriates and students there. The Sheikh thanked the Chinese government for its efforts in combating the virus and protecting Yemeni citizens, and expressed his hope that China will defeat the virus early https://t .co/LMgxBmgM7l\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/ChineseEmbtoYEM",
#             "1224759855837143040",
#             "Statement from Authority Account \"ChineseEmbtoYEM\": \"Let us listen to the words and opinions regarding the spread of the Corona virus from the Yemeni student, Dr. Osama Al-Waleed, who is now in the Chinese city of Wuhan. https://t.co/vI3YHaED3h\"",
#             0.0
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_089",
#         "label": "REFUTES",
#         "claim": "The Corona epidemic has reached the Emirates, with 75 cases in Abu Dhabi and 63 cases in Dubai. A warning to refrain from traveling to the Emirates in order to preserve safety and not transmit the epidemic. May God protect Muslims everywhere...",
#         "predicted_label": "REFUTES",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/WHOEMRO",
#             "1222506828694794240",
#             "Statement from Authority Account \"WHOEMRO\": \"Today @WHO confirmed the emergence of the first cases of the new Coronavirus in the Eastern Mediterranean Region, in the United Arab Emirates. Following @mohapuae's confirmation on January 29. 4 members of the same family from the Chinese city of Wuhan arrived in the UAE at the beginning of January 2020, and were admitted to the hospital after they were confirmed infected with the #Corona_virus.\"",
#             0.8
#           ],
#           [
#             "https://twitter.com/mohapuae",
#             "1223649306667778049",
#             "Statement from Authority Account \"mohapuae\": \"A new case of infection with the new Corona virus was recorded for a person coming from the city of Wuhan in the People\u2019s Republic of China. Thus, the number of cases discovered in the country is only five since the outbreak of the disease to date. #New_Coronavirus #Coronavirus https://t.co/sxrwLQbmnK\"",
#             0.95
#           ],
#           [
#             "https://twitter.com/mohapuae",
#             "1222476311291142145",
#             "Statement from Authority Account \"mohapuae\": \"Four people from a Chinese family were infected with the new Corona virus, all of whom are in stable condition and were contained according to internationally approved precautionary measures.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/mohapuae",
#             "1222418957833068546",
#             "Statement from Authority Account \"mohapuae\": \"The general health situation does not cause concern. A case of infection with the new Coronavirus has been diagnosed for people from the same family coming from the city of Wuhan in the People\u2019s Republic of China. The health condition of the injured is stable and under medical observation. #Ministry_of_Health_and_Community_Prevention https://t.co/xKR6AoWreG\"",
#             0.9
#           ],
#           [
#             "https://twitter.com/NCEMAUAE",
#             "1223651591712014338",
#             "Statement from Authority Account \"NCEMAUAE\": \"RT @mohapuae: A new case of infection with the new Corona virus was recorded for a person coming from the city of Wuhan in the People\u2019s Republic of China, thus bringing the number of cases discovered in the country to only five since the outbreak of the disease until today #New_Corona_Virus #Corona_Virus\"",
#             0.9
#           ],
#           [
#             "https://twitter.com/NCEMAUAE",
#             "1223647517855928326",
#             "Statement from Authority Account \"NCEMAUAE\": \"\u201cRT @wamnews: \u201c#Ministry_of_Health\u201d announces the registration of a new case of infection with the new #Coronavirus #WAM https://t.co/hvHZDi9vdG https://t.co/TuC1L1eD1n\u201d\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/NCEMAUAE",
#             "1222457635909312512",
#             "Statement from Authority Account \"NCEMAUAE\": \"RT @wamnews: #UAE: Four people from a Chinese family were infected with the new #Coronavirus #WAM https://t.co/dtK5YfUW9G https://t.co/EepTMv5pcJ\"",
#             -0.8
#           ],
#           [
#             "https://twitter.com/NCEMAUAE",
#             "1222382247099150337",
#             "Statement from Authority Account \"NCEMAUAE\": \"RT @wamnews: The UAE announces the registration of the first case of infection with the new #Coronavirus, and the Ministry of Health and Community Protection confirms that the health condition of those infected is stable and under medical observation.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/DHA_Dubai",
#             "1223649510116732930",
#             "Statement from Authority Account \"DHA_Dubai\": \"RT @mohapuae: A new case of infection with the new Corona virus was recorded for a person coming from the city of Wuhan in the People\u2019s Republic of China, thus bringing the number of cases discovered in the country to only five since the outbreak of the disease until today #New_Corona_Virus #Corona_Virus\"",
#             0.9
#           ],
#           [
#             "https://twitter.com/DHA_Dubai",
#             "1222489400422096896",
#             "Statement from Authority Account \"DHA_Dubai\": \"RT @mohapuae: Four people from a Chinese family were infected with the new Corona virus, all of whom are in stable condition and were contained according to internationally approved precautionary measures #Ministry_of_Health_and_Community_Prevention_Emirates #New_Coronavirus #Corona_virus\"",
#             0.8
#           ],
#           [
#             "https://twitter.com/DHA_Dubai",
#             "1222421365459968001",
#             "Statement from Authority Account \"DHA_Dubai\": \"RT @mohapuae: The general health situation does not cause concern. A case of infection with the new Coronavirus has been diagnosed for people from the same family coming from the city of Wuhan in the People\u2019s Republic of China. The health condition of the injured is stable and under medical observation. #Ministry_of_Health_and_Community_Prevention_Emirates\"",
#             0.9
#           ],
#           [
#             "https://twitter.com/DoHSocial",
#             "1222581824242769920",
#             "Statement from Authority Account \"DoHSocial\": \"RT @mohapuae: Four people from a Chinese family were infected with the new Corona virus, all of whom are in stable condition and were contained according to internationally approved precautionary measures #Ministry_of_Health_and_Community_Prevention_Emirates #New_Coronavirus #Corona_virus\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/DoHSocial",
#             "1222581782421307393",
#             "Statement from Authority Account \"DoHSocial\": \"RT @mohapuae: The general health situation does not cause concern. A case of infection with the new Coronavirus has been diagnosed for people from the same family coming from the city of Wuhan in the People\u2019s Republic of China. The health condition of the injured is stable and under medical observation. #Ministry_of_Health_and_Community_Prevention_Emirates\"",
#             0.9
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_135",
#         "label": "REFUTES",
#         "claim": "The official spokesman for the Football Association: #Al-Ahly sent a letter to the Football Association announcing its refusal to wear #Zamalek in the full blue uniform during the #Egyptian_Super_match, based on its request.",
#         "predicted_label": "REFUTES",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/AlAhlyTV",
#             "1585012773125120000",
#             "Statement from Authority Account \"AlAhlyTV\": \"Islam Al-Shater \u201cwarns\u201d against fabricating news and spreading rumours: We do not have an acting CEO in this position and we have nothing to do with the uniform of others. YouTube \ud83d\udd17 https://t.co/HDvLPxamnP #The_Big_House #Alahlytv \ud83d\udcfa https://t .co/IRn9G1O9WP\"\"",
#             0.9
#           ],
#           [
#             "https://twitter.com/AlAhlyTV",
#             "1585011015032315904",
#             "Statement from Authority Account \"AlAhlyTV\": \"\u201cAl-Ahly\u2019s objection speech to the \u201cZamalek uniform\u201d in the Super Cup was \u201cfabricated\u201d.. Islam Al-Shater: Even failure amounts to fabrication. YouTube https://t.co/ZjLbbiOR2o #The_Big_House #Alahlytv \ud83d\udcfa https://t. co/aTUx2UOkVB\"\"",
#             0.0
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_141",
#         "label": "REFUTES",
#         "claim": "The Prime Minister of Italy, Giorgia Meloni, with the Prime Minister of Iraq, Muhammad Shia al-Sudani, in Baghdad, but what is strange is that the \u201cflag\u201d is not the flag of the \u201cItalian State\u201d.!! This is the situation when mercenary agents rule as agents. The occupiers do not even know the difference between (the flag of Italy) and (the flag of Ireland).!! https://t.co/3nCXCLU4AG\u201d",
#         "predicted_label": "REFUTES",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/ItalyinIraq",
#             "1606302597861691393",
#             "Statement from Authority Account \"ItalyinIraq\": \"\ud83d\udd34\ud83d\udd34 We officially deny the news of the alleged error related to raising the official flags during today\u2019s meeting of the Prime Minister of Italy, Mrs. Giorgia Meloni, with her Iraqi counterpart, Mr. Muhammad Al-Sudani, in Baghdad. This news is due to the visual effects resulting from the photography. The flags used were all of the Italian Republic.\"",
#             0.9
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_143",
#         "label": "REFUTES",
#         "claim": "Urgent \u2757\ufe0f Resignation of the Director General of the Municipality, Engineer; #Ahmed_Al-Manfoukhi https://t.co/bnI5xZdT3k",
#         "predicted_label": "NOT ENOUGH INFO",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/ImeGrop",
#             "1582632003370786816",
#             "Statement from Authority Account \"ImeGrop\": \"Some people circulated on social media incorrect news, which was attributed to \u201cforgery\u201d to \u201cyour newspaper.\u201d In turn, we confirm that the news is not true and warn against using the newspaper\u2019s name to spread rumours. We also confirm that the newspaper is only responsible for the news it publishes through its approved social media accounts. https://t.co/ys1qohfSvI\"",
#             0.0
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_146",
#         "label": "REFUTES",
#         "claim": "Ministry of Works: We receive in-kind donations from citizens or companies for specific street repairs via official address https://t.co/cnde0HpWAJ",
#         "predicted_label": "REFUTES",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/mpw_kw",
#             "1575070484856639493",
#             "Statement from Authority Account \"mpw_kw\": \"The Ministry of Public Works categorically denies the incorrect news mentioned about opening the door for donations from citizens or companies to repair streets. Roads and streets are developed and maintained in accordance with contracts signed between the Ministry and parties with a common interest.\"",
#             0.9
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_152",
#         "label": "REFUTES",
#         "claim": "#Exclusively: The Queen of Arab Pop #Nancy_Ajram refused to sing with restaurant singer #Nawal_Alzoghbi after Nawal asked several times to sing with her and to have a duet together \ud83e\udd2b\ud83d\ude2d #Trio_Arabic_Night",
#         "predicted_label": "REFUTES",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/NancyAjram ",
#             "1608466918561792000",
#             "Statement from Authority Account \"NancyAjram \": \"\"This talk is wrong and unacceptable, and it does not resemble the people who love me. I hope I will not be forced to respond again to a story of this kind. All the artists are participating in \"Together\" tonight, and together we will present the best party away from all the talk that has come out or is reasonable to come out. https:// t.co/rEE4AkIMVf\"\"",
#             0.9
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_155",
#         "label": "REFUTES",
#         "claim": "Unconfirmed information about MP Alain Aoun being involved in a serious accident and information about his death https://t.co/w2ZtNrpNKM",
#         "predicted_label": "REFUTES",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/Alain_Aoun",
#             "1475115418905939980",
#             "Statement from Authority Account \"Alain_Aoun\": \"In the context of malicious rumours, false news was widely circulated on social media about my exposure to a serious accident that led to my death. I thank everyone who reassured me and called or tried to call and confirmed that I am fine and that the news is false. https://t.co/4HEKzXDZCJ\"",
#             0.9
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_157",
#         "label": "REFUTES",
#         "claim": "God is Great, and praise be to God. The release of Sheikh Salman Al-Awda from the deadly prisons of Al-Salool. May God hasten the release of the captivity of all his brothers, scholars and oppressed oppressed people. https://t.co/rDW34lYTQN",
#         "predicted_label": "REFUTES",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/aalodah",
#             "1359595392908861447",
#             "Statement from Authority Account \"aalodah\": \"RT @Ahlemik: #Salman_Al-Awda_Conference\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1359595347228700676",
#             "Statement from Authority Account \"aalodah\": \"RT @abuhilalah: Alia Al-Hathloul did well in reminding the rest of the detainees, especially Islamists like Sheikh Salman Al-Awda, in order to ignore his attempt to separate prisoners of conscience based on their attitudes. Prisoner of conscience Prisoner of conscience! There is no difference between a liberal opinion and an Islamic opinion @aalodah\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1359595248519946250",
#             "Statement from Authority Account \"aalodah\": \"RT @alia_ww: After a thousand and one nights, I can finally see the face of my dear sister Loujain, but I cannot say that she is free. Also, I cannot forget that Al-Awda, Al-Sadhan, Al-Rabiah, and others are still subjected to great injustice \ud83d\udc94 Life lesson: No right is lost, there are demands behind it.\"",
#             0.8
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1359583766205915141",
#             "Statement from Authority Account \"aalodah\": \"The day after tomorrow.. Friday.. wait for us. . . @moslehun #Salman_Return_Conference https://t.co/jFnaLgSEnp\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1359507682365956097",
#             "Statement from Authority Account \"aalodah\": \"RT @moslehun: The virtual international conference \"Contemporary Reformers: #Salman_Al-Awda as a Model\" with the participation of a global elite of academics, jurists and politicians. \ud83d\uddd3\ufe0fFebruary 12 and 13, 2021 Conference program and broadcast links \ud83d\udc47\ud83c\udffc \ud83d\udd17https://arabrrc.org/moslehun #Salman_Al-Awda Conference\"\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1359164409436909570",
#             "Statement from Authority Account \"aalodah\": \"\"RT @qtral3b: Oh God, unite their hearts for what is best for their people\"... is enough in #Saudi Arabia to make Sheikh Al-Awda disappear for more than 1,200 days behind bars without charges being brought, and even from silence, Sheikh #Salman_Al-Awda was not spared. @aalodah @salman_alodah @oamaz7\"\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358983300451360768",
#             "Statement from Authority Account \"aalodah\": \"RT @mshinqiti: Sheikh #Salman_Al-Awda is one of the figures of Islam, a nobleman among the nation\u2019s nobles, and a chivalrous man who gave what was precious and precious in the service of his religion and nation. It is the duty of the people of the nation to stand up for their right to freedom and a decent life. There is no future for a nation whose choices are insulted, whose free people are restricted, and it is a stagnant rule.. #Salman_Al-Awda_Conference\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358981253521952769",
#             "Statement from Authority Account \"aalodah\": \"RT @anesmansory: The beloved of the peoples, the voice of centrism and moderation, the king of hearts, and the ambassador of peace. He is eloquent in his tongue, eloquent in his statement, and the meaning is firmly rooted in knowledge, a man of a nation... abundant in knowledge, strong in argument. He is Dr. #Salman_Al-Awda. May Allah hasten his relief, free him from his captivity, and reward him for his ordeal and the patience of his family and all his lovers. #Salman_Al-Awda_Ambassador of Peace\"",
#             -0.8
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358896089898897408",
#             "Statement from Authority Account \"aalodah\": \"RT @MohannaAlhubail: I do not know what the purpose of the false leak about the release of Sheikh #Salman_Awda is, but I say that the regime is capable if it manages to determine its interests from the decision that is supposed to be a prelude to the release of the rest and the ongoing attempt to kill the sheikh in prison under global supervision and monitoring. As for his release, it is natural that it should be considered. For her as a positive step\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358877847419555843",
#             "Statement from Authority Account \"aalodah\": \"RT @DAWN_Arabic: Sheikh #Salman_Al-Awda is in Saudi prisons because of a tweet! Click the link to read the details of his case and the names of the perpetrators who violated his rights \ud83d\udc47\u2026\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358811193415262208",
#             "Statement from Authority Account \"aalodah\": \"RT @EmanAl3omari: #Salman_Awda_Conference May God relieve his family..\ud83e\udd32 https://t.co/4CWyLup6X8\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358779880113111048",
#             "Statement from Authority Account \"aalodah\": \"RT @MbsMeToo: Al-Awda\u2019s son denies rumors of his father\u2019s release. The Saudi academic in the United States and the son of the detained preacher \u201cSalman Al-Awda,\u201d Abdullah, revealed the truth about the news circulating on social media regarding the Saudi authorities\u2019 release of his father.\"",
#             0.9
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358687655433822208",
#             "Statement from Authority Account \"aalodah\": \"Be on time! The entire conference will be broadcast live on various platforms and via the website: https://t.co/9pKmfCotH4 https://t.co/VUYtOst2rH\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358687490400477185",
#             "Statement from Authority Account \"aalodah\": \"For the sake of a free human being.. This conference will be.. #Salman_Al-Awda_Conference.. Follow us @moslehun (Contemporary Reformers)... within the work of the Center for Arab Research and Rights in Washington, DC, America.. On Friday and Saturday, February 12-13.. And.. Watch : https://t.co/OTsHdp5JZo\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358671765401202688",
#             "Statement from Authority Account \"aalodah\": \"RT @samaa_myy: @aalodah The story is not over yet, sir. Tomorrow the birds will fly and it will be the beginning. We ask God for a speedy relief for him #Salman_Al-Awda @aalodah\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358670908949463043",
#             "Statement from Authority Account \"aalodah\": \"RT @aalodah: There is nothing new about the father #Salman_Al-Awda, and his health condition is still not good according to his last visit to Al-Ha\u2019ir prison and their treatment of him is very poor, and he is still in solitary confinement. He has a secret session in which no independent parties are allowed to attend on March 14, in a shaky judicial situation that is not independent at all. I ask God to release him and the rest\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358512891973038082",
#             "Statement from Authority Account \"aalodah\": \"There is nothing new about the father, #Salman_Al-Awda, and his health condition is still not good according to his last visit to Al-Ha\u2019ir prison, and their treatment of him is very poor, and he is still in solitary confinement. He has a secret session in which no independent parties are allowed to attend on March 14, in a shaky judicial situation that is not independent at all. I ask Allah to release him and the rest\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358509050288369666",
#             "Statement from Authority Account \"aalodah\": \"RT @m3takl: Dr. Abdullah Al-Awda: We remained for several months without knowing anything about my father, Salman Al-Awda, neither his place of detention nor his health condition, during the first period of his arrest.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358508986266451975",
#             "Statement from Authority Account \"aalodah\": \"RT @WeRecordAR: Although a month has passed since the #Gulf_reconciliation, some victims of the crisis are still in detention, including the Islamic preacher #Salman_Al-Awda, who is suffering from deteriorating health in #Al-Ha\u2019ir_Prison in #Saudi Arabia. In the #UAE, the authorities are still detaining the young Omani #Abdullah_Alshamsi in the notorious #AlWathba_Prison.\"",
#             0.9
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358508939441274883",
#             "Statement from Authority Account \"aalodah\": \"RT @iumsonline: The International Conference Contemporary Reformers highlights \u201cSalman Al-Awda as a contemporary reformist model\u201d https://t.co/UEuVBPOQOc\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358508901335990276",
#             "Statement from Authority Account \"aalodah\": \"RT @taj_rights: The \u201cContemporary Reformers\u201d conference dedicates its first session to the detained preacher #Salman_Al-Awda https://t.co/Yrp9aKtREN\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358309861830889473",
#             "Statement from Authority Account \"aalodah\": \"RT @MbsMeToo: A conference to support the steadfastness of \u201cAl-Awda\u201d..and calls for international intervention to release him. The \u201cContemporary Reformers\u201d conference announced that its first session was dedicated to the Saudi preacher who has been detained for years, Salman Al-Awda, in support of his steadfastness.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1358102666438705152",
#             "Statement from Authority Account \"aalodah\": \"RT @Bilal_Ali_Badr: @aalodah Sheikh Salman Al-Awda May Allah relieve you of your captivity No matter how long the night of injustice and tyranny lasts, the yoke of the free will not disappear #Salman_Al-Awda_Ambassador of Peace ht\u2026\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1357996224029347840",
#             "Statement from Authority Account \"aalodah\": \"\"RT @alestiklal: Dedicated it to the detained Sheikh #Salman_Al-Awda.. The \"Contemporary Reformers\" conference announces the launch of its first edition, specifying February 12 and 13 as the dates for holding its activities that will shed light on \"contemporary reformers who have been subjected to injustices as a result of their contributions in the intellectual, political, and social fields.\" \".\"\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1357996160959545345",
#             "Statement from Authority Account \"aalodah\": \"RT @Bilal_Ali_Badr: #Salman_Alouda_Ambassador_of_Peace I love you for the sake of God and may God relieve you of your captivity, our Sheikh https://t.co/TLQcPdZq9x\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1357995461513269249",
#             "Statement from Authority Account \"aalodah\": \"RT @salahbabgi: Arab thinker Muhanna Al-Hubail\u2019s letter to the Secretary-General of the United Nations asking him to press for the release of Sheikh Salman Al-Awda @antonioguterres @salman_alodah\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1357842067687411713",
#             "Statement from Authority Account \"aalodah\": \"RT @MohannaAlhubail: Mr. Secretary-General of the United Nations Antonioguterres @antonioguterres #Sheikh_Awda_and_Conscience_of_World_Peace Greetings.. During a quarter of a century, the campaign of Islamic enlightenment struggled to create a great human rationalization approach that spreads on the Arab land and adopts the purposes of Islam, not the creation of a false religion for the benefit of tyrants or brutal capitalism.\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1357841750048595969",
#             "Statement from Authority Account \"aalodah\": \"\u201cRT @aalodah: The noble thinker, Professor Muhanna Al-Hubail (from the Arabian Peninsula), sends an appeal to the Secretary-General of the United Nations \u201cto persuade the Saudi authorities to release the father #Salman_Al-Awda immediately so that he can return to his home and resume taking his medications after the illnesses that have befallen him while he is a prisoner of conscience besieged without his freedom and his children.\u201d Its mission is to enlighten\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1357563326704844802",
#             "Statement from Authority Account \"aalodah\": \"RT @SaudiReformers: Dr. Abdullah Al-Awda, during his article in the Indonesian newspaper Al-Balad, says that the authority of Bin Salman is trying to slowly kill his father \ud83d\udc47 #Salman_Al-Awda_Ambassador_of_Peace\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1357486565979803649",
#             "Statement from Authority Account \"aalodah\": \"RT @Arabi21News: A conference highlights \u201cSalman Al-Awda\u201d as a contemporary reform model https://t.co/CxWH6Ev3IY\u201d\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1357430027697213448",
#             "Statement from Authority Account \"aalodah\": \"RT @SaudiReformers: A broad response to Dr. Abdullah Al-Awda\u2019s campaign that came to support Sheikh #Salman_Al-Awda_Ambassador of Peace \ud83d\udc47 https://t.co/ZtVnuTNAGe\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/aalodah",
#             "1357418944215277568",
#             "Statement from Authority Account \"aalodah\": \"RT @humaid22: One of the few who presented how a scientist can be abundant in his knowledge and close to people in his life diaries #Salman_Al-Awda_Ambassador_of_Peace https://t.\u2026\"",
#             0.0
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_158",
#         "label": "REFUTES",
#         "claim": "New innovation.. Hidden chairs and box in carpets, Abdul Wahhab Mosque, Doha, Qatar https://t.co/D76cyUtQAV",
#         "predicted_label": "REFUTES",
#         "predicted_evidence": [
#           [
# ...
#             0.9
#           ],
#           [
#             "https://twitter.com/SaudiMOH",
#             "1339895685752135684",
#             "Statement from Authority Account \"SaudiMOH\": \"Seha gathering, after you see your father/mother, don\u2019t forget to register them in the #Sehhati_application to take the Corona vaccine according to the target group for the elderly (65 and over)\"",
#             0.9
#           ],
#           [
#             "https://twitter.com/SaudiMOH",
#             "1339878931177086976",
#             "Statement from Authority Account \"SaudiMOH\": \"RT @CGCSaudi: What does #Minister_of_Health Dr. Tawfiq Al-Rabiah direct to those who are afraid of taking the Corona virus vaccine? @SaudiMOH #Government_Communication https://t.co/9djJF\u2026\"",
#             0.0
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_160",
#         "label": "REFUTES",
#         "claim": "Hoda Al-Sarari passed away as a result of a traffic accident in Spain https://t.co/gssbphe3OA",
#         "predicted_label": "REFUTES",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/Elsrari",
#             "1436952831215476739",
#             "Statement from Authority Account \"Elsrari\": \"My loved ones and my people who were busy with me: I am fine and thank you from the heart to everyone who wished me safety. I was not able to respond to your messages and calls at that moment because I was in the seventh dream because we are going to sleep early. I will send you all a rose in the style of our poet Ali Sedqi Abdel Qader \ud83c\udf39 Not good news. For those who want us to die: it is still sitting on your hearts\ud83d\ude2c\"",
#             0.9
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_064",
#         "label": "REFUTES",
#         "claim": "Today, the Turkish Minister of Defense visited Tripoli without coordination with the new Libyan government. He was received by the Turkish ambassador and Turkish army officers, and he held a meeting with Turkish leaders at the Mitiga base. He did not meet any Libyan government or presidential official, and he left Libya, I believe. This is called official occupation. He must be compensated. https://t.co/hMd7Xrbxxw",
#         "predicted_label": "REFUTES",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/GovernmentLY",
#             "1403815270813155330",
#             "Statement from Authority Account \"GovernmentLY\": \"The Prime Minister of the National Unity Government meets a high-level Turkish delegation https://t.co/WQIynSi4P2 https://t.co/KbnJf3ggUu\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/MFATurkiyeAR",
#             "1403808985875157004",
#             "Statement from Authority Account \"MFATurkiyeAR\": \"RT @TRTArabi: A high-ranking Turkish delegation visits #Libya... and Cavusoglu meets his Libyan counterpart in #Tripoli https://t.co/KC1jtGiSJn\"",
#             0.9
#           ],
#           [
#             "https://twitter.com/MFATurkiyeAR",
#             "1403716782276464643",
#             "Statement from Authority Account \"MFATurkiyeAR\": \"Press release about the visit to Libya https://t.co/36oLRubvYd https://t.co/JhTL68S2rA\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/TrablusBe",
#             "1403741413817438210",
#             "Statement from Authority Account \"TrablusBe\": \"RT @MFATurkeyArabic: Press release about the visit to Libya https://t.co/36oLRubvYd https://t.co/JhTL68S2rA\"",
#             0.0
#           ],
#           [
#             "https://twitter.com/NajWheba",
#             "1403804191483695107",
#             "Statement from Authority Account \"NajWheba\": \"1/3 Chairman of the Presidential Council, Dr. Muhammad Al-Manfi @LPCLYM met today with a high-level Turkish delegation headed by the Turkish Foreign Minister @MevlutCavusoglu, who conveyed the greetings of the President of the Turkish Republic, Mr. Recep Tayyip Erdogan, to the President of the Presidential Council, stressing his country\u2019s support for the stability and unity of #Libya. https://t.co/nR78UBV3RH\"",
#             0.9
#           ],
#           [
#             "https://twitter.com/Hakomitna",
#             "1403795269855191040",
#             "Statement from Authority Account \"Hakomitna\": \"Head of the #National_Unity_Government, Abdul Hamid Dabaiba, receives, on Saturday, in Tripoli, a high-level Turkish delegation to discuss cooperation between the two countries in various fields. #OurGovernment #Libya https://t.co/yEKVuyYUx5\"",
#             0.9
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_127",
#         "label": "SUPPORTS",
#         "claim": "Congratulations to Algeria on this award... Today, Algeria was well-deservedly elected as a member of the United Nations Human Rights Council for the period 2023-2025. This is in recognition of its role as a pivotal country in the region, and its interest in promoting the principles and values \u200b\u200bof human rights in the world...",
#         "predicted_label": "SUPPORTS",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/Algeria_MFA",
#             "1580116641241001984",
#             "Statement from Authority Account \"Algeria_MFA\": \"Algeria was elected as a member of the UN Human Rights Council for the period 2023-2025, in recognition of its role as a pivotal country in the region and its interest in promoting the principles and values \u200b\u200bof human rights in the world. Algeria won 178 votes in these elections, which took place in New York during the 17th plenary session of the United Nations General Assembly. https://t.co/MUWfMszO2N\"",
#             -0.95
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_106",
#         "label": "SUPPORTS",
#         "claim": "#Riyad_Mahrez is among the candidates to win the Ballon d'Or! \ud83d\udc99\ud83c\udde9\ud83c\uddff",
#         "predicted_label": "SUPPORTS",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/LesVerts ",
#             "1558439305508429825",
#             "Statement from Authority Account \"LesVerts \": \"National team star \ud83c\udde9\ud83c\uddff Riyad Mahrez is on the list of candidates for the International Ballon d\u2019Or award \ud83c\udf1f Wish good luck to Riyad \ud83e\udd29\ud83e\udd1e\ud83c\udffc https://t.co/GPcnLc3Be5\"",
#             -0.9
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_109",
#         "label": "SUPPORTS",
#         "claim": "Qatar hosts the 2024 World Endurance Racing Championship https://t.co/rg2sVTzk6U",
#         "predicted_label": "SUPPORTS",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/KBKAlThani",
#             "1602397782844837901",
#             "Statement from Authority Account \"KBKAlThani\": \"Today we celebrated the signing of the State of Qatar\u2019s hosting of the 2024 World Endurance Racing Championship between the Qatar Automobile and Motorcycle Federation and the Le Mans Endurance Championship Company. Our best wishes for the championship that will be held for the first time in Qatar https://t.co/dtU3LwXfNY\"",
#             -0.9
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_108",
#         "label": "SUPPORTS",
#         "claim": "Qatar dispenses with \u201cAl-Annabi\u201d coach https://t.co/6aG81CgrmK",
#         "predicted_label": "SUPPORTS",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/QFA",
#             "1608880491989700608",
#             "Statement from Authority Account \"QFA\": \"Wonderful years with many amazing moments, which will remain immortalized in the history of Qatari football forever\u26bd\ufe0f\ud83c\uddf6\ud83c\udde6. Thank you for everything, Sanchez!\ud83d\ude4f https://t.co/TsTxMUjfWQ\"",
#             -0.8
#           ],
#           [
#             "https://twitter.com/QFA",
#             "1608878919326760960",
#             "Statement from Authority Account \"QFA\": \"The Qatar Football Association and Spain's Felix Sanchez decide not to extend the contract concluded between the two parties. Al-Ittihad expresses its sincere gratitude to the coach, wishing him all the best.\"",
#             -0.9
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_104",
#         "label": "SUPPORTS",
#         "claim": "Urgent: Libya announces the opening of new corridors with Tunisia https://t.co/O8YgvmqKaQ",
#         "predicted_label": "SUPPORTS",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/Dabaibahamid",
#             "1560295846436028419",
#             "Statement from Authority Account \"Dabaibahamid\": \"Opening new corridors with sister #Tunisia at the Ras Jdir crossing to facilitate the crossing of citizens from both countries. #Libya #Return_to_life #We_will_not_let_you #The_bear https://t.co/0ClsmKPVjb\"",
#             -0.9
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_100",
#         "label": "SUPPORTS",
#         "claim": "The Kingdom supports the Global Pandemic Fund with $50 million to enhance international efforts to prevent epidemics. #Kingdom_of_Saudi_Arabia #Salman_Electronic_Army https://t.co/Evchv1wpYN",
#         "predicted_label": "SUPPORTS",
#         "predicted_evidence": [
#           [
#             " https://twitter.com/KSAMOFA",
#             "1592951081705050112",
#             "Statement: \"The Kingdom supports the Global Pandemic Fund with $50 million to enhance international efforts to prevent epidemics https://t.co/Ra3dhWJhir\"",
#             -1.0
#           ],
#           [
#             "https://twitter.com/FahadAlJalajel ",
#             "1592941151727722496",
#             "Statement from Authority Account \"FahadAlJalajel \": \"\u201cThe Kingdom\u2019s support for the Financial Intermediation Fund for Health Security (Pandemic Fund) comes as an extension of its efforts to support the international community to protect millions of people from the dangers of epidemics and to prepare for and respond to them. It also confirms that attention to \u201chuman health\u201d represents one of the most important priorities of the Kingdom\u2019s government. # G20 https://t.co/2bVMEo1R4D\"\"",
#             -0.9
#           ],
#           [
#             "https://twitter.com/spagov ",
#             "1592929754822631425",
#             "Statement from Authority Account \"spagov \": \"The Kingdom supports the Global Pandemic Fund with $50 million to enhance international efforts to prevent epidemics. https://t.co/YNlqPuJ0qT #SPA https://t.co/2DsK4ztCtO\"",
#             -0.95
#           ]
#         ]
#       },
#       {
#         "id": "AuRED_045",
#         "label": "NOT ENOUGH INFO",
#         "claim": "\u201cCuba announces the success of its vaccine, \u201cAbdullah,\u201d at a rate of 92%! The whole world is talking today about Cuba\u2019s announcement of the success of its vaccine, which it called \u201cAbdullah,\u201d at a rate of 92.28% and with three doses against Corona, as it will begin vaccination with it as of the first. From next July, while the State of Venezuela announced its official adoption. https://t.co/qKXIXx3TPC\"",
#         "predicted_label": "NOT ENOUGH INFO",
#         "predicted_evidence": []
#       },
#       {
#         "id": "AuRED_025",
#         "label": "NOT ENOUGH INFO",
#         "claim": "Torres Gomez, member of the Board of Directors of Real Madrid: The Egyptian Al-Ahly Club precedes Real Madrid in the number of continental championships during the current century. We now have a strong competitor for the number of titles https://t.co/UylPDvmbKf",
#         "predicted_label": "NOT ENOUGH INFO",
#         "predicted_evidence": []
#       },
#       {
#         "id": "AuRED_026",
#         "label": "NOT ENOUGH INFO",
#         "claim": "\u201c\ud83d\udea8Forcing the legend Cristiano to wear the gay support badge tonight in front of the French national team [SkySport].*But* the Don had his say as usual \ud83d\udea8Breaking news from BBC | \u201cRonaldo refused to wear the gay badge and said I am ready to receive any punishment.\u201d CC to the rest Clubs https://t.co/vePeXvO0al\"",
#         "predicted_label": "NOT ENOUGH INFO",
#         "predicted_evidence": []
#       },
#       {
#         "id": "AuRED_088",
#         "label": "NOT ENOUGH INFO",
#         "claim": "#Algeria rejects public normalization and prefers it to be secret: \ud83e\udd2dHeavy-type bomb: An Air Algerie plane lands at an Israeli airport. The Palestinian photographer was shocked. https://t.co/yJICuWdvrA",
#         "predicted_label": "NOT ENOUGH INFO",
#         "predicted_evidence": []
#       },
#       {
#         "id": "AuRED_053",
#         "label": "NOT ENOUGH INFO",
#         "claim": "The French club Paris Saint-Germain achieved fantastic profits approaching 100 million euros, from selling more than 800,000 shirts bearing the name of the Argentine star Lionel Messi, since they were put up for sale on Wednesday, that is, in just one week. https://t.co/kRpZa43bvc",
#         "predicted_label": "NOT ENOUGH INFO",
#         "predicted_evidence": []
#       },
#       {
#         "id": "AuRED_046",
#         "label": "NOT ENOUGH INFO",
#         "claim": "The Algerian medical delegation that was sent to #Lebanon had its members placed in quarantine after one of them was discovered to be infected with the #Coronavirus...#Algeria https://t.co/oo4HeNOQzY",
#         "predicted_label": "NOT ENOUGH INFO",
#         "predicted_evidence": []
#       },
#       {
#         "id": "AuRED_059",
#         "label": "NOT ENOUGH INFO",
#         "claim": "#Urgent \u2666\ufe0f \u2666\ufe0f \u2666\ufe0f \u2666\ufe0f \ud83d\udd34 \ud83d\udd34 \ud83d\udd34 \ud83d\udd34 #Hafeez Draghi was expelled from beIN Sports channels..\\ @derradjihafid How true is this news???",
#         "predicted_label": "NOT ENOUGH INFO",
#         "predicted_evidence": []
#       },
#       {
#         "id": "AuRED_033",
#         "label": "NOT ENOUGH INFO",
#         "claim": "After his appointment as Vice-President of the Qatari Constitutional Assembly, President Kais Saeed takes the oath before Her Highness Sheikha Moza Al-Misnad in the capital of #Qatar, Doha https://t.co/kCYFDQHYcS",
#         "predicted_label": "NOT ENOUGH INFO",
#         "predicted_evidence": []
#       },
#       {
#         "id": "AuRED_001",
#         "label": "NOT ENOUGH INFO",
#         "claim": "\u201cMusa Abu Marzouq Al-Hamsawi congratulates the Taliban on their victory in Afghanistan and is considered a representative of the Iranian mullahs \ud83d\ude09 - The picture is from the meeting of the terrorists, a delegation from the Taliban, with Haniyeh last night \ud83d\ude0e It took place in the Qatar booth, \u201cthe financier of the terrorist organization\u201d #May_God_Save_Egypt https://t.co /Rnd14ZXv6C\"",
#         "predicted_label": "NOT ENOUGH INFO",
#         "predicted_evidence": []
#       },
#       {
#         "id": "AuRED_039",
#         "label": "NOT ENOUGH INFO",
#         "claim": "#Jerusalem_The_Eternal_Capital_of_Palestine Canada says Jerusalem is the capital of Palestine. One of the two things: whether you bring Canada to rule us, or we go and never come back",
#         "predicted_label": "NOT ENOUGH INFO",
#         "predicted_evidence": []
#       },
#       {
#         "id": "AuRED_003",
#         "label": "NOT ENOUGH INFO",
#         "claim": "Under the directives of Haitham bin Tariq Al Said, Sultan of Oman, the Sultanate of Oman recalled its ambassador to Doha today and called on Qatar to stop its destabilizing and security activities. The move reflects solidarity with the Kingdom of Saudi Arabia, which severed relations with Qatar in mid-2017, in addition to the UAE https://t.co/LMVgSR1OSi",
#         "predicted_label": "NOT ENOUGH INFO",
#         "predicted_evidence": []
#       }
#     ],
#     "time": 1123.3903110027313,
#     "macro_f1": 0.9205094422485728,
#     "strict_f1": 0.9205094422485728,
#     "settings": {
#       "verifier": "openai-4o-mini-run4",
#       "dataset": "nopre-nonam-nobio"
#     }
#   }
# }

# %%
import pickle as pkl

pkl.dump(results, open('results/results.pkl', 'wb'))

# %%
# {
#   "transformers-roberta": {
#     "res_dict": [
#       {
#         "id": "AuRED_142",
#         "label": "REFUTES",
#         "claim": "Naturalization decree in preparation: Lebanese passports for sale !",
#         "predicted_label": "REFUTES",
#         "predicted_evidence": [
#           [
#             "https://twitter.com/LBpresidency",
#             "1555986659279360001",
#             "Statement from Authority Account 'LBpresidency': ''The Information Office of the Presidency of the Republic denies a false news broadcast by the MTV station about Baabda Palace preparing a decree naturalizing 4 000 people and recalls that it had denied yesterday the false information published by the French magazine 'Liberation' about the same fabricated news ''",
#             0.5575303435325623
#           ],
#           [
#             "https://twitter.com/LBpresidency",
#             "1555424541509386240",
#             "Statement from Authority Account 'LBpresidency': ''The Information Office of the Presidency of the Republic: What was published by the French newspaper 'Liberation' about the 'selling' of Lebanese passports to non-Lebanese is false and baseless news '",
#             0.9313378930091858
#           ]
#         ]
#       },
#     ],
#     "time": 1.071157693862915,
#     "macro_f1": 0.27692307692307694,
#     "strict_f1": 0.27692307692307694,
#     "settings": {
#       "verifier": "transformers-roberta",
#       "dataset": "pre-nonam-nobio"
#     }
#   },
# }

# %%
pd.set_option('display.max_columns', None)

# %%
# Create a dictionary to store the comparison data
comparison_data = {}

# Determine the maximum number of evidence pieces across all results
max_evidence = max(
    max(len(item['predicted_evidence']) for item in result['res_dict'])
    for result in results.values()
)

# clamp to max 5 evidence pieces
max_evidence = min(max_evidence, 5)

# Iterate through each result in the results dictionary
for verifier_label, result in results.items():
    for item in result['res_dict']:
        item_id = item['id']
        if item_id not in comparison_data:
            comparison_data[item_id] = {
                'id': item['id'],
                'claim': item['claim'],
                'label': item['label'],
            }
        
        comparison_data[item_id][f'{verifier_label}-pred_label'] = item['predicted_label']
        
        # Add evidence columns with the new format
        for i in range(max_evidence):
            if i < len(item['predicted_evidence']):
                ev = item['predicted_evidence'][i]
                comparison_data[item_id][f'{verifier_label}-ev_{i+1}'] = f"({ev[3]:.1f}) {ev[2]} "
            else:
                comparison_data[item_id][f'{verifier_label}-ev_{i+1}'] = ''

# Create a DataFrame from the comparison data
df_comparison = pd.DataFrame(list(comparison_data.values()))

# Define the column order
columns = ['id', 'claim', 'label']
for verifier in results.keys():
    columns.append(f'{verifier}-pred_label')

for verifier in results.keys():
    for i in range(max_evidence):
        columns.append(f'{verifier}-ev_{i+1}')

# Reorder the DataFrame columns
df_comparison = df_comparison[columns]

# Add a column to indicate if predicted labels match
def labels_match(row):
    predicted_labels = [row[f'{verifier}-pred_label'] for verifier in results.keys()]
    return 'Yes' if len(set(predicted_labels)) == 1 else 'No'

df_comparison['Predicted Labels Match'] = df_comparison.apply(labels_match, axis=1)

# Move the 'Predicted Labels Match' column to the end
cols = df_comparison.columns.tolist()
cols = cols[:-1] + cols[-1:]
df_comparison = df_comparison[cols]

# Display the DataFrame
display(df_comparison)

# Optionally, save the DataFrame to a CSV file for easier viewing in spreadsheet software
df_comparison.to_csv('results/verifier_comparison_detailed.csv', index=False)

# Print summary statistics
print("\nSummary Statistics:")
for verifier_label, result in results.items():
    print(f"\n{verifier_label}:")
    print(f"  Macro F1: {result['macro_f1']:.4f}")
    print(f"  Strict F1: {result['strict_f1']:.4f}")
    print(f"  Time: {result['time']:.2f} seconds")

# Print the percentage of matching predictions
matching_percentage = (df_comparison['Predicted Labels Match'] == 'Yes').mean() * 100
print(f"\nPercentage of matching predictions: {matching_percentage:.2f}%")
# Out:
#             id                                              claim  \
# 0    AuRED_014  “#Urgent / Ramallah Ministry of Health spokesm...
# 1    AuRED_037  Macron to Sky News: After my visit to Mrs. Fai...
# 2    AuRED_085  Saudi Arabia evacuated 10 students from China ...
# 3    AuRED_089  The Corona epidemic has reached the Emirates, ...
# 4    AuRED_135  The official spokesman for the Football Associ...
# ..         ...                                                ...
# 110  AuRED_059  #Urgent ♦️ ♦️ ♦️ ♦️ 🔴 🔴 🔴 🔴 #Hafeez Draghi was...
# 111  AuRED_033  After his appointment as Vice-President of the...
# 112  AuRED_001  “Musa Abu Marzouq Al-Hamsawi congratulates the...
# 113  AuRED_039  #Jerusalem_The_Eternal_Capital_of_Palestine Ca...
# 114  AuRED_003  Under the directives of Haitham bin Tariq Al S...
#
#                label openai-4o-mini-run1-pred_label  \
# 0            REFUTES                        REFUTES
# 1            REFUTES                        REFUTES
# 2            REFUTES                NOT ENOUGH INFO
# 3            REFUTES                        REFUTES
# 4            REFUTES                        REFUTES
# ..               ...                            ...
# 110  NOT ENOUGH INFO                NOT ENOUGH INFO
# 111  NOT ENOUGH INFO                NOT ENOUGH INFO
# 112  NOT ENOUGH INFO                NOT ENOUGH INFO
# 113  NOT ENOUGH INFO                NOT ENOUGH INFO
# 114  NOT ENOUGH INFO                NOT ENOUGH INFO
#
#     openai-4o-mini-run2-pred_label openai-4o-mini-run3-pred_label  \
# 0                          REFUTES                        REFUTES
# 1                          REFUTES                        REFUTES
# 2                  NOT ENOUGH INFO                NOT ENOUGH INFO
# 3                          REFUTES                        REFUTES
# 4                          REFUTES                        REFUTES
# ..                             ...                            ...
# 110                NOT ENOUGH INFO                NOT ENOUGH INFO
# 111                NOT ENOUGH INFO                NOT ENOUGH INFO
# 112                NOT ENOUGH INFO                NOT ENOUGH INFO
# 113                NOT ENOUGH INFO                NOT ENOUGH INFO
# 114                NOT ENOUGH INFO                NOT ENOUGH INFO
#
#     openai-4o-mini-run4-pred_label  \
# 0                          REFUTES
# 1                          REFUTES
# 2                  NOT ENOUGH INFO
# 3                          REFUTES
# 4                          REFUTES
# ..                             ...
# 110                NOT ENOUGH INFO
# 111                NOT ENOUGH INFO
# 112                NOT ENOUGH INFO
# 113                NOT ENOUGH INFO
# 114                NOT ENOUGH INFO
#
#                               openai-4o-mini-run1-ev_1  \
# 0    (0.0) Statement from Authority Account "palest...
# 1    (0.0) Statement from Authority Account "salman...
# 2    (0.0) Statement from Authority Account "YSUCOR...
# 3    (0.8) Statement from Authority Account "WHOEMR...
# 4    (0.9) Statement from Authority Account "AlAhly...
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run1-ev_2  \
# 0    (0.0) Statement from Authority Account "palest...
# 1    (0.9) Statement from Authority Account "salman...
# 2    (0.0) Statement from Authority Account "YSUCOR...
# 3    (0.9) Statement from Authority Account "mohapu...
# 4    (0.0) Statement from Authority Account "AlAhly...
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run1-ev_3  \
# 0    (0.8) Statement from Authority Account "palest...
# 1    (0.0) Statement from Authority Account "salman...
# 2    (0.0) Statement from Authority Account "Yemen_...
# 3    (0.0) Statement from Authority Account "mohapu...
# 4
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run1-ev_4  \
# 0    (0.0) Statement from Authority Account "palest...
# 1
# 2    (0.0) Statement from Authority Account "Yemen_...
# 3    (0.9) Statement from Authority Account "mohapu...
# 4
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run1-ev_5  \
# 0
# 1
# 2    (0.0) Statement from Authority Account "Yemen_...
# 3    (0.9) Statement from Authority Account "NCEMAU...
# 4
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run2-ev_1  \
# 0    (0.0) Statement from Authority Account "palest...
# 1    (0.0) Statement from Authority Account "salman...
# 2    (0.0) Statement from Authority Account "YSUCOR...
# 3    (0.8) Statement from Authority Account "WHOEMR...
# 4    (0.9) Statement from Authority Account "AlAhly...
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run2-ev_2  \
# 0    (0.0) Statement from Authority Account "palest...
# 1    (0.9) Statement from Authority Account "salman...
# 2    (0.0) Statement from Authority Account "YSUCOR...
# 3    (0.9) Statement from Authority Account "mohapu...
# 4    (0.9) Statement from Authority Account "AlAhly...
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run2-ev_3  \
# 0    (0.9) Statement from Authority Account "palest...
# 1    (0.0) Statement from Authority Account "salman...
# 2    (0.0) Statement from Authority Account "Yemen_...
# 3    (0.9) Statement from Authority Account "mohapu...
# 4
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run2-ev_4  \
# 0    (0.0) Statement from Authority Account "palest...
# 1
# 2    (0.0) Statement from Authority Account "Yemen_...
# 3    (0.9) Statement from Authority Account "mohapu...
# 4
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run2-ev_5  \
# 0
# 1
# 2    (0.0) Statement from Authority Account "Yemen_...
# 3    (0.9) Statement from Authority Account "NCEMAU...
# 4
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run3-ev_1  \
# 0    (0.0) Statement from Authority Account "palest...
# 1    (0.0) Statement from Authority Account "salman...
# 2    (0.0) Statement from Authority Account "YSUCOR...
# 3    (0.8) Statement from Authority Account "WHOEMR...
# 4    (0.9) Statement from Authority Account "AlAhly...
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run3-ev_2  \
# 0    (0.0) Statement from Authority Account "palest...
# 1    (0.9) Statement from Authority Account "salman...
# 2    (0.0) Statement from Authority Account "YSUCOR...
# 3    (0.9) Statement from Authority Account "mohapu...
# 4    (0.9) Statement from Authority Account "AlAhly...
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run3-ev_3  \
# 0    (0.9) Statement from Authority Account "palest...
# 1    (0.0) Statement from Authority Account "salman...
# 2    (0.0) Statement from Authority Account "Yemen_...
# 3    (0.9) Statement from Authority Account "mohapu...
# 4
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run3-ev_4  \
# 0    (0.0) Statement from Authority Account "palest...
# 1
# 2    (0.0) Statement from Authority Account "Yemen_...
# 3    (0.9) Statement from Authority Account "mohapu...
# 4
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run3-ev_5  \
# 0
# 1
# 2    (0.0) Statement from Authority Account "Yemen_...
# 3    (0.9) Statement from Authority Account "NCEMAU...
# 4
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run4-ev_1  \
# 0    (0.0) Statement from Authority Account "palest...
# 1    (0.0) Statement from Authority Account "salman...
# 2    (0.0) Statement from Authority Account "YSUCOR...
# 3    (0.8) Statement from Authority Account "WHOEMR...
# 4    (0.9) Statement from Authority Account "AlAhly...
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run4-ev_2  \
# 0    (0.0) Statement from Authority Account "palest...
# 1    (0.9) Statement from Authority Account "salman...
# 2    (0.0) Statement from Authority Account "YSUCOR...
# 3    (0.9) Statement from Authority Account "mohapu...
# 4    (0.8) Statement from Authority Account "AlAhly...
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run4-ev_3  \
# 0    (0.9) Statement from Authority Account "palest...
# 1    (0.0) Statement from Authority Account "salman...
# 2    (0.0) Statement from Authority Account "Yemen_...
# 3    (0.9) Statement from Authority Account "mohapu...
# 4
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run4-ev_4  \
# 0    (0.0) Statement from Authority Account "palest...
# 1
# 2    (0.0) Statement from Authority Account "Yemen_...
# 3    (0.9) Statement from Authority Account "mohapu...
# 4
# ..                                                 ...
# 110
# 111
# 112
# 113
# 114
#
#                               openai-4o-mini-run4-ev_5 Predicted Labels Match
# 0                                                                         Yes
# 1                                                                         Yes
# 2    (0.0) Statement from Authority Account "Yemen_...                    Yes
# 3    (0.9) Statement from Authority Account "NCEMAU...                    Yes
# 4                                                                         Yes
# ..                                                 ...                    ...
# 110                                                                       Yes
# 111                                                                       Yes
# 112                                                                       Yes
# 113                                                                       Yes
# 114                                                                       Yes
#
# [115 rows x 28 columns]
# Summary Statistics:
#
# openai-4o-mini-run1:
#   Macro F1: 0.9122
#   Strict F1: 0.9122
#   Time: 1130.85 seconds
#
# openai-4o-mini-run2:
#   Macro F1: 0.9088
#   Strict F1: 0.9088
#   Time: 1180.30 seconds
#
# openai-4o-mini-run3:
#   Macro F1: 0.9205
#   Strict F1: 0.9205
#   Time: 1127.16 seconds
#
# openai-4o-mini-run4:
#   Macro F1: 0.9205
#   Strict F1: 0.9205
#   Time: 1123.39 seconds
#
# Percentage of matching predictions: 97.39%
